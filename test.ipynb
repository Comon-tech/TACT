# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import discord

my_id = 304721494276308992

intents = discord.Intents.default()
intents.message_content = True
client = discord.Client(intents=intents)
await client.login(os.getenv("DISCORD_TOKEN"))
user: discord.User = await client.fetch_user(my_id)

print(user.display_name)
# Out:
# 𝘼𝙢𝙗𝙧𝙖𝙩𝙤𝙡𝙢

# %% [markdown]
# # Database

# %%
from core.db.user import DbUser

user = DbUser.load(1000)
print(user)

user.inventory.append("a")
print(user)
user.save()
# Out:
# id=1000 xp=69 level=1 inventory=['Cat', 'Cat', 'Cat', 'Squi', 'Squi', 'Squi', 'Squi', 'a']
# id=1000 xp=69 level=1 inventory=['Cat', 'Cat', 'Cat', 'Squi', 'Squi', 'Squi', 'Squi', 'a', 'a']
